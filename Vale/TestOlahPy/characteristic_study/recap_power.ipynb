# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
power_2019 = pd.read_excel("power_2019.xlsx", sheet_name="Sheet1")
#power_2019

vibration_2019 = = pd.read_excel("vibration_2019.xlsx", sheet_name="Sheet1")
vibration_2019 = vibration_2019.drop(columns=['TimeStamp'])
#vibration_2019

data_2019 = pd.concat([power_2019, vibration_2019], axis=1)
data_2019
# Out:
#                   TimeStamp  U-LGS1-Active-Power-AI  U-LGS1-Reactive-Power-AI  \
# 0       01/01/2019 00:00:00                   43.79                     33.97
# 1       01/01/2019 00:01:00                   43.80                     33.96
# 2       01/01/2019 00:02:00                   43.80                     33.96
# 3       01/01/2019 00:03:00                   43.80                     33.96
# 4       01/01/2019 00:04:00                   43.80                     33.96
# ...                     ...                     ...                       ...
# 525595  12/31/2019 23:55:59                   48.52                     24.21
# 525596  12/31/2019 23:56:59                   47.98                     27.03
# 525597  12/31/2019 23:57:59                   47.44                     25.88
# 525598  12/31/2019 23:58:59                   46.90                     22.38
# 525599  12/31/2019 23:59:59                   42.95                     18.85
#
# ...

# %%
power_2020 = pd.read_excel("power_2020.xlsx", sheet_name="Sheet1")
#power_2020

vibration_2020 = pd.read_excel("vibration_2020.xlsx", sheet_name="Sheet1")
vibration_2020 = vibration_2020.drop(columns=['TimeStamp'])
#vibration_2020

data_2020 = pd.concat([power_2020, vibration_2020], axis=1)
data_2020
# Out:
#                   TimeStamp  U-LGS1-Active-Power-AI  U-LGS1-Reactive-Power-AI  \
# 0       01/01/2020 00:00:00                   42.88                     18.79
# 1       01/01/2020 00:01:00                   43.65                     22.85
# 2       01/01/2020 00:02:00                   44.42                     20.13
# 3       01/01/2020 00:03:00                   45.19                     17.41
# 4       01/01/2020 00:04:00                   45.96                     22.23
# ...                     ...                     ...                       ...
# 527035  12/31/2020 23:55:59                    9.23                     13.69
# 527036  12/31/2020 23:56:59                    9.23                     13.69
# 527037  12/31/2020 23:57:59                    9.23                     13.69
# 527038  12/31/2020 23:58:59                    9.24                     13.69
# 527039  12/31/2020 23:59:59                    9.24                     13.69
#
# ...

# %%
power_2021 = pd.read_excel("power_2021.xlsx", sheet_name="Sheet1")
#power_2021

vibration_2021 = pd.read_excel("vibration_2021.xlsx", sheet_name="Sheet1")
vibration_2021 = vibration_2021.drop(columns=['TimeStamp'])
#vibration_2021

data_2021 = pd.concat([power_2021, vibration_2021], axis=1)
data_2021
# Out:
#                   TimeStamp  U-LGS1-Active-Power-AI  U-LGS1-Reactive-Power-AI  \
# 0       01/01/2021 00:00:00                    9.24                     13.69
# 1       01/01/2021 00:01:00                    9.24                     13.69
# 2       01/01/2021 00:02:00                    9.24                     13.69
# 3       01/01/2021 00:03:00                    9.24                     13.69
# 4       01/01/2021 00:04:00                    9.24                     13.69
# ...                     ...                     ...                       ...
# 525595  12/31/2021 23:55:59                   46.11                     15.10
# 525596  12/31/2021 23:56:59                   46.13                     10.03
# 525597  12/31/2021 23:57:59                   46.11                     14.22
# 525598  12/31/2021 23:58:59                   46.09                     14.49
# 525599  12/31/2021 23:59:59                   46.08                     14.68
#
# ...

# %%
power_2022 = pd.read_excel("power_2022.xlsx", sheet_name="Sheet1")
#power_2022

vibration_2022 = pd.read_excel("vibration_2022.xlsx", sheet_name="Sheet1")
vibration_2022 = vibration_2022.drop(columns=['TimeStamp'])
#vibration_2022

data_2022 = pd.concat([power_2022, vibration_2022], axis=1)
data_2022
# Out:
#                   TimeStamp  U-LGS1-Active-Power-AI  U-LGS1-Reactive-Power-AI  \
# 0       01/01/2022 00:00:00                   46.08                     14.68
# 1       01/01/2022 00:01:00                   46.06                     12.97
# 2       01/01/2022 00:02:00                   46.04                     11.25
# 3       01/01/2022 00:03:00                   46.03                      9.53
# 4       01/01/2022 00:04:00                   46.01                      9.68
# ...                     ...                     ...                       ...
# 525595  12/31/2022 23:55:59                   37.61                     19.08
# 525596  12/31/2022 23:56:59                   37.61                     19.07
# 525597  12/31/2022 23:57:59                   37.61                     19.07
# 525598  12/31/2022 23:58:59                   37.61                     19.07
# 525599  12/31/2022 23:59:59                   37.61                     19.07
#
# ...

# %%
power_2023 = pd.read_excel("power_2023.xlsx", sheet_name="Sheet1")
#power_2023

vibration_2023 = pd.read_excel("vibration_2023.xlsx", sheet_name="Sheet1")
vibration_2023 = vibration_2023.drop(columns=['TimeStamp'])
#vibration_2023

data_2023 = pd.concat([power_2023, vibration_2023], axis=1)
data_2023
# Out:
#                   TimeStamp  U-LGS1-Active-Power-AI  U-LGS1-Reactive-Power-AI  \
# 0       01/01/2023 00:00:00                   37.61                     19.07
# 1       01/01/2023 00:01:00                   37.61                     19.07
# 2       01/01/2023 00:02:00                   37.61                     19.07
# 3       01/01/2023 00:03:00                   37.61                     19.07
# 4       01/01/2023 00:04:00                   37.61                     19.07
# ...                     ...                     ...                       ...
# 525595  12/31/2023 23:55:59                   48.51                     19.61
# 525596  12/31/2023 23:56:59                   48.61                     20.63
# 525597  12/31/2023 23:57:59                   48.65                     21.60
# 525598  12/31/2023 23:58:59                   48.69                     14.94
# 525599  12/31/2023 23:59:59                   51.58                     22.07
#
# ...

# %% [markdown]
# Combine all power data

# %%
# all power and vibration data
data = pd.concat([data_2020, data_2021, data_2022, data_2023])
data
# Out:
#                   TimeStamp  U-LGS1-Active-Power-AI  U-LGS1-Reactive-Power-AI  \
# 0       01/01/2020 00:00:00                   42.88                     18.79
# 1       01/01/2020 00:01:00                   43.65                     22.85
# 2       01/01/2020 00:02:00                   44.42                     20.13
# 3       01/01/2020 00:03:00                   45.19                     17.41
# 4       01/01/2020 00:04:00                   45.96                     22.23
# ...                     ...                     ...                       ...
# 525595  12/31/2023 23:55:59                   48.51                     19.61
# 525596  12/31/2023 23:56:59                   48.61                     20.63
# 525597  12/31/2023 23:57:59                   48.65                     21.60
# 525598  12/31/2023 23:58:59                   48.69                     14.94
# 525599  12/31/2023 23:59:59                   51.58                     22.07
#
# ...

# %%
# calculate total hours with load category
# high load : 55-60 MW
# low load : 10 MW
# normal load : 40-45 MW

conditions = [
    data['U-LGS1-Active-Power-AI'].isna(),
    (data['U-LGS1-Active-Power-AI'] < 1) & ((data['Governor Actual Speed'] > 0) & (data['Governor Actual Speed'] <= 260)),
    (data['U-LGS1-Active-Power-AI'] < 1) & ((data['Governor Actual Speed'] > 260) & (data['Governor Actual Speed'] <= 280)),
    (data['U-LGS1-Active-Power-AI'] < 1),
    (data['U-LGS1-Active-Power-AI'] >= 1) & (data['U-LGS1-Active-Power-AI'] < 20),
    (data['U-LGS1-Active-Power-AI'] >= 20) & (data['U-LGS1-Active-Power-AI'] < 40),
    (data['U-LGS1-Active-Power-AI'] >= 40) & (data['U-LGS1-Active-Power-AI'] < 50),
    (data['U-LGS1-Active-Power-AI'] >= 50) & (data['U-LGS1-Active-Power-AI'] < 65),
    (data['U-LGS1-Active-Power-AI'] >= 65)
]

choices = ['N/A data', 'Start-Up and Shutdown Process', 'Speed No Load', 'Unit Shut Down', 'Low Load', 'Rough Zone', 'Part Load', 'Best Efficiency Point', 'High Load']
data['Power Class'] = np.select(conditions, choices)

# data['TimeStamp'] = pd.to_datetime(data['TimeStamp'])

data['Year'] = data['TimeStamp'].dt.year
duration_per_class_per_year = data.groupby(['Year', 'Power Class']).size().unstack(fill_value=0) / 60

# Plotting
ax = duration_per_class_per_year.plot(kind='bar', stacked=True, figsize=(10, 25))

# Customizing the plot
plt.title('Duration of Power Load Per Year')
plt.xlabel('Year')
plt.ylabel('Total Duration (hours)')
plt.legend(title='Power Load Class')

# Adding values on each stacked bar
for container in ax.containers:
    ax.bar_label(container, label_type='center', fmt='%.1f')
 
plt.show()

# %%
# calculate total hours with grid category

conditions = [
    data['U-LGS1-N75-15-0-AI'].isna(),
    (data['U-LGS1-N75-15-0-AI'] == 1.0),
    (data['U-LGS1-N75-15-0-AI'] == 0.0),
]

choices = ['N/A data', 'FCE Grid', 'Auxiliary Grid']
data['Grid Class'] = np.select(conditions, choices)

#power_data['TimeStamp'] = pd.to_datetime(power_data['TimeStamp'])

data['Year'] = data['TimeStamp'].dt.year
duration_per_class_per_year = data.groupby(['Year', 'Grid Class']).size().unstack(fill_value=0) / 60

# Plotting
ax = duration_per_class_per_year.plot(kind='bar', stacked=True, figsize=(10, 10))

# Customizing the plot
plt.title('Duration of Grid Selection Per Year')
plt.xlabel('Year')
plt.ylabel('Total Duration (hours)')
plt.legend(title='Grid Selection')

# Adding values on each stacked bar
for container in ax.containers:
    ax.bar_label(container, label_type='center', fmt='%.1f')

plt.show()

# %% [markdown]
# Characteristic study

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# data_2023['TimeStamp'] = pd.to_datetime(data_2023['TimeStamp'])
data['Year'] = data['TimeStamp'].dt.year

# Filter out NaN values in the 'power' column and vibration columns
# df = df.dropna(subset=['U-LGS1-Active-Power-AI'] + list(df.columns[df.columns.str.startswith('vibration')]))

conditions = [
    data['U-LGS1-Active-Power-AI'].isna(),
    (data['U-LGS1-Active-Power-AI'] < 1) & ((data['Governor Actual Speed'] > 0) & (data['Governor Actual Speed'] <= 260)),
    (data['U-LGS1-Active-Power-AI'] < 1) & ((data['Governor Actual Speed'] > 260) & (data['Governor Actual Speed'] <= 280)),
    (data['U-LGS1-Active-Power-AI'] < 1),
    (data['U-LGS1-Active-Power-AI'] >= 1) & (data['U-LGS1-Active-Power-AI'] < 20),
    (data['U-LGS1-Active-Power-AI'] >= 20) & (data['U-LGS1-Active-Power-AI'] < 40),
    (data['U-LGS1-Active-Power-AI'] >= 40) & (data['U-LGS1-Active-Power-AI'] < 50),
    (data['U-LGS1-Active-Power-AI'] >= 50) & (data['U-LGS1-Active-Power-AI'] < 65),
    (data['U-LGS1-Active-Power-AI'] >= 65)
]

choices = ['N/A data', 'Start-Up and Shutdown Process', 'Speed No Load', 'Unit Shut Down', 'Low Load', 'Rough Zone', 'Part Load', 'Best Efficiency Point', 'High Load']
data['Power Class'] = np.select(conditions, choices)

# Verify the categorization
print(data['Power Class'].value_counts())

# Step 1: Calculate Statistical Parameters for Vibration Data
vibration_stats = data.groupby('Power Class')[['Governor Actual Speed', 'UGB X-Displacement', 'UGB Y-Displacement', 'LGB X-Displacement', 'LGB Y-Displacement', 'TGB X-Displacement', 'TGB Y-Displacement']].agg(['mean', 'var', 'std']).reset_index()
print(vibration_stats)

# Step 2: Plot PDF of Vibration Data Columns by Power Class
fig, axes = plt.subplots(nrows=7, ncols=1, figsize=(10, 70))

for i, col in enumerate(['Governor Actual Speed', 'UGB X-Displacement', 'UGB Y-Displacement', 'LGB X-Displacement', 'LGB Y-Displacement', 'TGB X-Displacement', 'TGB Y-Displacement']):
    for cls in choices:
        sns.kdeplot(data=data[data['Power Class'] == cls][col], ax=axes[i], label=f'Power Class: {cls}', shade=True)
    axes[i].set_title(f'Distribution of {col}\nAcross Power Classes')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Density')
    axes[i].legend(title='Power Class')
    axes[i].grid()

plt.tight_layout()
plt.show()
# Out:
# Part Load                        721986
# Best Efficiency Point            573756
# Low Load                         423572
# Rough Zone                       247641
# Unit Shut Down                   116924
# Speed No Load                      8692
# N/A data                           8506
# Start-Up and Shutdown Process      2630
# High Load                           133
# Name: Power Class, dtype: int64
#                      Power Class Governor Actual Speed               \
#                                                   mean          var
# 0          Best Efficiency Point            274.532688     3.371032
# 1                      High Load            273.058346    12.663458
# 2                       Low Load            274.357007    18.142889
# 3                       N/A data            268.841111  1682.228287
# 4                      Part Load            274.740336     1.710808
# 5                     Rough Zone            274.704603     0.333020
# ...

# %%
data
# Out:
#                  TimeStamp  U-LGS1-Active-Power-AI  U-LGS1-Reactive-Power-AI  \
# 0      2020-01-01 00:00:00                   42.88                     18.79
# 1      2020-01-01 00:01:00                   43.65                     22.85
# 2      2020-01-01 00:02:00                   44.42                     20.13
# 3      2020-01-01 00:03:00                   45.19                     17.41
# 4      2020-01-01 00:04:00                   45.96                     22.23
# ...                    ...                     ...                       ...
# 525595 2023-12-31 23:55:59                   48.51                     19.61
# 525596 2023-12-31 23:56:59                   48.61                     20.63
# 525597 2023-12-31 23:57:59                   48.65                     21.60
# 525598 2023-12-31 23:58:59                   48.69                     14.94
# 525599 2023-12-31 23:59:59                   51.58                     22.07
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from fitter import Fitter

# Assuming 'data' is your DataFrame containing vibration data and 'choices' is your list of power classes

# Step 1: Fit distributions to vibration data columns for each power class
vibration_data = data[['Governor Actual Speed', 'UGB X-Displacement', 'UGB Y-Displacement', 
                       'LGB X-Displacement', 'LGB Y-Displacement', 'TGB X-Displacement', 
                       'TGB Y-Displacement']].dropna()

# Dictionary to store fitted distributions for each power class
fitted_distributions = {}

for power_class in choices:
    # Fit distributions for the current power class
    fitter = Fitter(vibration_data[data['Power Class'] == power_class])
    fitter.fit()

    # Get the best fitting distribution
    best_fit_name = fitter.get_best(method='sumsquare_error')[0]
    fitted_distributions[power_class] = best_fit_name

# Step 2: Plot PDFs of the best fitting distributions for each power class
fig, axes = plt.subplots(nrows=len(vibration_data.columns), ncols=1, figsize=(10, 10))

for i, col in enumerate(vibration_data.columns):
    for power_class in choices:
        best_fit_name = fitted_distributions[power_class]
        best_dist = getattr(fitter, best_fit_name)
        sns.kdeplot(data=vibration_data[data['Power Class'] == power_class][col], ax=axes[i], label=f'Power Class: {power_class}, Best Fit: {best_fit_name}', shade=True)

    axes[i].set_title(f'Distribution of {col} Across Power Classes')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Density')
    axes[i].legend(title='Power Class')
    axes[i].grid()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/maasyraf/Documents/research/Predict-CBM/Vale/TestOlahPy/characteristic_study/recap_power.ipynb Cell 13 line 5
#       <a href='vscode-notebook-cell:/home/maasyraf/Documents/research/Predict-CBM/Vale/TestOlahPy/characteristic_study/recap_power.ipynb#X31sZmlsZQ%3D%3D?line=2'>3</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/home/maasyraf/Documents/research/Predict-CBM/Vale/TestOlahPy/characteristic_study/recap_power.ipynb#X31sZmlsZQ%3D%3D?line=3'>4</a> import seaborn as sns
# ----> <a href='vscode-notebook-cell:/home/maasyraf/Documents/research/Predict-CBM/Vale/TestOlahPy/characteristic_study/recap_power.ipynb#X31sZmlsZQ%3D%3D?line=4'>5</a> from fitter import Fitter
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#data_2023['TimeStamp'] = pd.to_datetime(data_2023['TimeStamp'])
data_2023['Year'] = data_2023['TimeStamp'].dt.year

# Filter out NaN values in the 'power' column and vibration columns
# df = df.dropna(subset=['U-LGS1-Active-Power-AI'] + list(df.columns[df.columns.str.startswith('vibration')]))

conditions = [
    (data_2023['U-LGS1-N75-15-0-AI'] == 1.0),
    (data_2023['U-LGS1-N75-15-0-AI'] == 0.0),
]

choices = ['FCE Grid', 'Auxiliary Grid']
data_2023['Grid Class'] = np.select(conditions, choices)

# Verify the categorization
print(data_2023['Grid Class'].value_counts())

# Step 1: Calculate Statistical Parameters for Vibration Data
vibration_stats = data_2023.groupby('Grid Class')[['Governor Actual Speed', 'UGB X-Displacement', 'UGB Y-Displacement', 'LGB X-Displacement', 'LGB Y-Displacement', 'TGB X-Displacement', 'TGB Y-Displacement']].agg(['mean', 'var', 'std']).reset_index()
print(vibration_stats)

# Step 2: Plot PDF of Vibration Data Columns by Power Class
fig, axes = plt.subplots(nrows=7, ncols=1, figsize=(10, 70))

for i, col in enumerate(['Governor Actual Speed', 'UGB X-Displacement', 'UGB Y-Displacement', 'LGB X-Displacement', 'LGB Y-Displacement', 'TGB X-Displacement', 'TGB Y-Displacement']):
    for cls in choices:
        sns.kdeplot(data=data_2023[data_2023['Grid Class'] == cls][col], ax=axes[i], label=f'Grid Class: {cls}', shade=True)
    axes[i].set_title(f'Distribution of {col}\nAcross Grid Classes')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Density')
    axes[i].legend(title='Grid Class')
    axes[i].grid()

plt.tight_layout()
plt.show()
# Out:
# FCE Grid          375075
# Auxiliary Grid    150247
# 0                    278
# Name: Grid Class, dtype: int64
#        Grid Class Governor Actual Speed                            \
#                                    mean           var         std
# 0               0            200.289388  14491.886840  120.382253
# 1  Auxiliary Grid            274.042907    129.399853   11.375406
# 2        FCE Grid            269.903139   1311.098666   36.209096
#
#   UGB X-Displacement                         UGB Y-Displacement               \
#                 mean          var        std               mean          var
# 0         147.739784  7372.929150  85.865762         149.436295  7386.594896
# 1         190.017166   171.310037  13.088546         196.663419   168.105464
# 2         185.843534   659.537497  25.681462         190.342414   668.705580
#
#               ... LGB X-Displacement LGB Y-Displacement               \
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Create a date range and some sample data
date_rng = pd.date_range(start='1/1/2010', end='31/12/2016', freq='T')
np.random.seed(42)
power_data = np.random.uniform(low=0, high=100, size=(len(date_rng),))
vibration_data = np.random.uniform(low=0, high=10, size=(len(date_rng), 5))  # 5 columns of vibration data
# Introduce some NaN values randomly
nan_indices = np.random.choice(len(date_rng), size=5000, replace=False)
power_data[nan_indices] = np.nan
vibration_data[nan_indices, :] = np.nan
df = pd.DataFrame(date_rng, columns=['timestamp'])
df['power'] = power_data
df[['vibration1', 'vibration2', 'vibration3', 'vibration4', 'vibration5']] = vibration_data

# Ensure the timestamp column is in datetime format
df['timestamp'] = pd.to_datetime(df['timestamp'])

# Filter out NaN values in the 'power' column and vibration columns
df = df.dropna(subset=['power'] + list(df.columns[df.columns.str.startswith('vibration')]))

# Categorize power data into 3 classes based on its values
conditions = [
    (df['power'] < 33),
    (df['power'] >= 33) & (df['power'] < 66),
    (df['power'] >= 66)
]
choices = ['Low', 'Medium', 'High']
df['power_class'] = np.select(conditions, choices, default='N/A')

# Verify the categorization
print(df['power_class'].value_counts())

# Extract year from the timestamp
df['year'] = df['timestamp'].dt.year

# Calculate duration (in hours) for each power class per year
duration_per_class_per_year = df.groupby(['year', 'power_class']).size().unstack(fill_value=0) / 60

# Plotting
ax = duration_per_class_per_year.plot(kind='bar', stacked=True, figsize=(10, 7), color=['blue', 'orange', 'green'])

# Customizing the plot
plt.title('Duration of Power Classes Per Year')
plt.xlabel('Year')
plt.ylabel('Total Duration (hours)')
plt.legend(title='Power Class')

# Adding values on each stacked bar
for container in ax.containers:
    labels = [f'{v.get_height():.1f}' if v.get_height() > 0 else '' for v in container]
    ax.bar_label(container, labels=labels, label_type='center')

plt.show()

# Step 1: Calculate Statistical Parameters for Vibration Data
vibration_stats = df.groupby('power_class')[['vibration1', 'vibration2', 'vibration3', 'vibration4', 'vibration5']].agg(['mean', 'var', 'std']).reset_index()
print(vibration_stats)

# Step 2: Plot PDF of Vibration Data Columns by Power Class
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(20, 5), sharey=True)

for i, col in enumerate(['vibration1', 'vibration2', 'vibration3', 'vibration4', 'vibration5']):
    for cls in choices:
        sns.kdeplot(data=df[df['power_class'] == cls][col], ax=axes[i], label=f'Power Class: {cls}', shade=True)
    axes[i].set_title(f'Distribution of {col}\nAcross Power Classes')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Density')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2296/4132291069.py:8: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   date_rng = pd.date_range(start='1/1/2010', end='31/12/2016', freq='T')
# High      1249598
# Medium    1213449
# Low       1212594
# Name: power_class, dtype: int64
#   power_class vibration1                     vibration2                      \
#                     mean       var       std       mean       var       std
# 0        High   4.994359  8.332886  2.886674   5.001327  8.338246  2.887602
# 1         Low   5.001080  8.327182  2.885686   5.001542  8.335609  2.887145
# 2      Medium   5.000745  8.330240  2.886216   4.999102  8.325377  2.885373
#
#   vibration3                     vibration4                     vibration5  \
#         mean       var       std       mean       var       std       mean
# ...
