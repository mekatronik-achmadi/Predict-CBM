# %% [markdown]
# # Preliminary Data Analysis

# %%
# import all necessary packages
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# load the data
db_data = pd.read_excel("LGS1_Overall_2023_minutes.xlsx", sheet_name="LGS#1 Jan 23")
db_data
# Out:
#                 TimeStamp  Active Power (MW)  Grid (Aux: 0 & FCE:1)  \
# 0     2023-01-01 00:00:01              37.61                      0
# 1     2023-01-01 00:01:01              37.61                      0
# 2     2023-01-01 00:02:01              37.61                      0
# 3     2023-01-01 00:03:01              37.61                      0
# 4     2023-01-01 00:04:01              37.61                      0
# ...                   ...                ...                    ...
# 44635 2023-01-31 23:55:58              37.98                      0
# 44636 2023-01-31 23:56:58              37.98                      0
# 44637 2023-01-31 23:57:58              37.99                      0
# 44638 2023-01-31 23:58:58              37.99                      0
# 44639 2023-01-31 23:59:59              38.00                      0
#
#        Reactive Power (MVAr)  Exc Voltage (Volt)  Exc Current (A)  \
# 0                      19.07              123.82           702.02
# 1                      19.07              122.04           702.02
# 2                      19.07              124.18           702.08
# 3                      19.07              126.24           705.61
# 4                      19.07              123.86           703.47
# ...                      ...                 ...              ...
# 44635                  24.91              128.18           751.15
# 44636                  24.91              134.63           746.71
# 44637                  24.91              134.74           748.44
# 44638                  24.91              131.77           745.78
# 44639                  24.91              128.73           745.72
#
#        V Phase 1 (Volt)  V Phase 2 (Volt)  V Phase 3 (Volt)  \
# 0                 10.77             10.73             10.84
# 1                 10.77             10.73             10.84
# 2                 10.77             10.73             10.84
# 3                 10.77             10.73             10.84
# 4                 10.77             10.73             10.84
# ...                 ...               ...               ...
# 44635             10.88             10.84             10.88
# 44636             10.88             10.84             10.88
# 44637             10.88             10.84             10.88
# 44638             10.88             10.84             10.88
# 44639             10.88             10.84             10.88
#
#        Current Phase 1 (A)  ...  LGB Metal Temp 2  LGB Oil Temp  \
# 0                     0.00  ...             53.00          70.0
# 1                     0.00  ...             53.00          70.0
# 2                     0.00  ...             53.00          70.0
# 3                     0.00  ...             53.00          70.0
# 4                     0.00  ...             53.00          70.0
# ...                    ...  ...               ...           ...
# 44635                 0.27  ...             55.00          71.0
# 44636                 0.26  ...             55.00          71.0
# 44637                 0.26  ...             54.02          71.0
# 44638                 0.25  ...             53.02          71.0
# 44639                 0.24  ...             53.98          71.0
#
#        Gen air Cooler Air Otlet Temp  Gen air Cooler Water Inlet Temp  \
# 0                              55.14                            61.01
# 1                              55.14                            61.02
# 2                              55.14                            61.03
# 3                              55.14                            61.04
# 4                              55.15                            61.05
# ...                              ...                              ...
# 44635                          58.72                            64.56
# 44636                          58.72                            64.53
# 44637                          58.71                            64.51
# 44638                          58.71                            64.48
# 44639                          58.70                            64.45
#
#        Gen air Cooler Water Otlet Temp  Gen Cooler Water Flow (LPM)  \
# 0                                59.31                      3795.33
# 1                                59.33                      3793.33
# 2                                59.34                      3795.49
# 3                                59.35                      3797.36
# 4                                59.36                      3796.19
# ...                                ...                          ...
# 44635                            63.00                      3872.81
# 44636                            63.00                      3862.35
# 44637                            63.00                      3859.04
# 44638                            63.00                      3865.32
# 44639                            63.00                      3861.98
#
#        UGB Cooling Water Flow (LPM)  LGB Cooling Water Flow (LPM)  \
# 0                             32.42                        945.70
# 1                             32.42                        943.88
# 2                             32.42                        945.63
# 3                             32.42                        945.73
# 4                             32.42                        946.02
# ...                             ...                           ...
# 44635                         32.42                        953.84
# 44636                         32.42                        953.21
# 44637                         32.42                        952.60
# 44638                         32.42                        953.43
# 44639                         32.42                        953.06
#
#        Lower Canal Level (msAL)  TailRace Level (msAL)
# 0                        308.10                 165.96
# 1                        308.10                 165.97
# 2                        308.10                 165.97
# 3                        308.10                 165.97
# 4                        308.10                 165.97
# ...                         ...                    ...
# 44635                    313.97                 165.99
# 44636                    313.92                 165.99
# 44637                    313.96                 165.99
# 44638                    313.97                 165.99
# 44639                    313.94                 165.99
#
# [44640 rows x 46 columns]

# %%
# checking all columns contains NaN
db_data.isnull().sum()
# Out:
# TimeStamp                           0
# Active Power (MW)                  13
# Grid (Aux: 0 & FCE:1)               0
# Reactive Power (MVAr)              13
# Exc Voltage (Volt)                 13
# Exc Current (A)                    13
# V Phase 1 (Volt)                   12
# V Phase 2 (Volt)                   12
# V Phase 3 (Volt)                   12
# Current Phase 1 (A)                12
# Current Phase 2 (A)                12
# Current Phase 3 (A)                12
# Modbus MVAr                        12
# Modbus MVA                         12
# PF (Cos Phi)                       12
# Freq (hz)                          12
# Speed (RPM)                        12
# WG Opening (%)                     13
# Speed (RPM).1                      13
# Penstock Pressure (Kg/cm2)         12
# Penstoc Flow (Cumecs)              13
# Turbine Flow (Cumecs)              13
# Eff (Cumecs/MW)                    13
# UGB X (µm)                         12
# UGB Y (µm)                         12
# LGB X (µm)                         12
# LGB Y (µm)                         12
# TGB X (µm)                         12
# TGB Y (µm)                         12
# Stator Winding temp 13             13
# Stator Winding temp 14             13
# Stator Winding temp 15             13
# Stator Core temp 12                13
# UGB Metal Temp                     13
# UGB Oil Temp                       13
# LGB Metal Temp 1                   13
# LGB Metal Temp 2                   13
# LGB Oil Temp                       13
# Gen air Cooler Air Otlet Temp      13
# Gen air Cooler Water Inlet Temp    13
# Gen air Cooler Water Otlet Temp    13
# Gen Cooler Water Flow (LPM)        12
# UGB Cooling Water Flow (LPM)       12
# LGB Cooling Water Flow (LPM)       12
# Lower Canal Level (msAL)           22
# TailRace Level (msAL)              13
# dtype: int64

# %%
# clear all column with NaN input
db_data = db_data.dropna(axis=0)
db_data = db_data.dropna(axis=1)
db_data
# Out:
#                 TimeStamp  Active Power (MW)  Grid (Aux: 0 & FCE:1)  \
# 0     2023-01-01 00:00:01              37.61                      0
# 1     2023-01-01 00:01:01              37.61                      0
# 2     2023-01-01 00:02:01              37.61                      0
# 3     2023-01-01 00:03:01              37.61                      0
# 4     2023-01-01 00:04:01              37.61                      0
# ...                   ...                ...                    ...
# 44635 2023-01-31 23:55:58              37.98                      0
# 44636 2023-01-31 23:56:58              37.98                      0
# 44637 2023-01-31 23:57:58              37.99                      0
# 44638 2023-01-31 23:58:58              37.99                      0
# 44639 2023-01-31 23:59:59              38.00                      0
#
#        Reactive Power (MVAr)  Exc Voltage (Volt)  Exc Current (A)  \
# 0                      19.07              123.82           702.02
# 1                      19.07              122.04           702.02
# 2                      19.07              124.18           702.08
# 3                      19.07              126.24           705.61
# 4                      19.07              123.86           703.47
# ...                      ...                 ...              ...
# 44635                  24.91              128.18           751.15
# 44636                  24.91              134.63           746.71
# 44637                  24.91              134.74           748.44
# 44638                  24.91              131.77           745.78
# 44639                  24.91              128.73           745.72
#
#        V Phase 1 (Volt)  V Phase 2 (Volt)  V Phase 3 (Volt)  \
# 0                 10.77             10.73             10.84
# 1                 10.77             10.73             10.84
# 2                 10.77             10.73             10.84
# 3                 10.77             10.73             10.84
# 4                 10.77             10.73             10.84
# ...                 ...               ...               ...
# 44635             10.88             10.84             10.88
# 44636             10.88             10.84             10.88
# 44637             10.88             10.84             10.88
# 44638             10.88             10.84             10.88
# 44639             10.88             10.84             10.88
#
#        Current Phase 1 (A)  ...  LGB Metal Temp 2  LGB Oil Temp  \
# 0                     0.00  ...             53.00          70.0
# 1                     0.00  ...             53.00          70.0
# 2                     0.00  ...             53.00          70.0
# 3                     0.00  ...             53.00          70.0
# 4                     0.00  ...             53.00          70.0
# ...                    ...  ...               ...           ...
# 44635                 0.27  ...             55.00          71.0
# 44636                 0.26  ...             55.00          71.0
# 44637                 0.26  ...             54.02          71.0
# 44638                 0.25  ...             53.02          71.0
# 44639                 0.24  ...             53.98          71.0
#
#        Gen air Cooler Air Otlet Temp  Gen air Cooler Water Inlet Temp  \
# 0                              55.14                            61.01
# 1                              55.14                            61.02
# 2                              55.14                            61.03
# 3                              55.14                            61.04
# 4                              55.15                            61.05
# ...                              ...                              ...
# 44635                          58.72                            64.56
# 44636                          58.72                            64.53
# 44637                          58.71                            64.51
# 44638                          58.71                            64.48
# 44639                          58.70                            64.45
#
#        Gen air Cooler Water Otlet Temp  Gen Cooler Water Flow (LPM)  \
# 0                                59.31                      3795.33
# 1                                59.33                      3793.33
# 2                                59.34                      3795.49
# 3                                59.35                      3797.36
# 4                                59.36                      3796.19
# ...                                ...                          ...
# 44635                            63.00                      3872.81
# 44636                            63.00                      3862.35
# 44637                            63.00                      3859.04
# 44638                            63.00                      3865.32
# 44639                            63.00                      3861.98
#
#        UGB Cooling Water Flow (LPM)  LGB Cooling Water Flow (LPM)  \
# 0                             32.42                        945.70
# 1                             32.42                        943.88
# 2                             32.42                        945.63
# 3                             32.42                        945.73
# 4                             32.42                        946.02
# ...                             ...                           ...
# 44635                         32.42                        953.84
# 44636                         32.42                        953.21
# 44637                         32.42                        952.60
# 44638                         32.42                        953.43
# 44639                         32.42                        953.06
#
#        Lower Canal Level (msAL)  TailRace Level (msAL)
# 0                        308.10                 165.96
# 1                        308.10                 165.97
# 2                        308.10                 165.97
# 3                        308.10                 165.97
# 4                        308.10                 165.97
# ...                         ...                    ...
# 44635                    313.97                 165.99
# 44636                    313.92                 165.99
# 44637                    313.96                 165.99
# 44638                    313.97                 165.99
# 44639                    313.94                 165.99
#
# [44618 rows x 46 columns]

# %%
# create correlation map of data
df = db_data
f = plt.figure(figsize=(40, 30))
plt.matshow(df.corr(), fignum=f.number)
plt.xticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);
# Out:
# /tmp/ipykernel_8164/2603953442.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.matshow(df.corr(), fignum=f.number)
